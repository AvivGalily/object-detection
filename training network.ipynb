# %%
# !nvidia -smi
# Out:
# /bin/bash: nvidia: command not found

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip "/content/gdrive/MyDrive/proj3/zip/images.zip" -d "/content/gdrive/MyDrive/proj3" #unzip dataset file that was saved in drive and was downlodad from roboflow dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/gdrive/MyDrive/proj3/train/Sphynx_205_jpg.rf.f7c5a41130f3916deed35f974c5d1df8.txt
#  extracting: /content/gdrive/MyDrive/proj3/train/_darknet.labels
#  extracting: /content/gdrive/MyDrive/proj3/train/american_bulldog_102_jpg.rf.f5d69d3ce15f380432ee6418448c144a.jpg
#  extracting: /content/gdrive/MyDrive/proj3/train/american_bulldog_102_jpg.rf.f5d69d3ce15f380432ee6418448c144a.txt
#  extracting: /content/gdrive/MyDrive/proj3/train/american_bulldog_104_jpg.rf.bd70dd5517696c5dfac1440ef69b0a7a.jpg
#  extracting: /content/gdrive/MyDrive/proj3/train/american_bulldog_104_jpg.rf.bd70dd5517696c5dfac1440ef69b0a7a.txt
#  extracting: /content/gdrive/MyDrive/proj3/train/american_bulldog_105_jpg.rf.7ff447c13447606deeab8329f180fe49.jpg
#  extracting: /content/gdrive/MyDrive/proj3/train/american_bulldog_105_jpg.rf.7ff447c13447606deeab8329f180fe49.txt
# ...

# %%
# %cd train
# Out:
# /content/gdrive/MyDrive/proj3/train

# %%
# %cd images
# Out:
# /content/gdrive/MyDrive/proj3/train/images

# %%
import os
import torch
from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.13.1+cu116 _CudaDeviceProperties(name='NVIDIA A100-SXM4-40GB', major=8, minor=0, total_memory=40536MB, multi_processor_count=108)

# %%
# create Ultralytics specific text file of training images
file = open("train.txt", "w") 
for root, dirs, files in os.walk("."):
    for filename in files:
      # print("../train/images/" + filename)
      if filename == "train.txt":
        pass
      else:
        file.write("../train/images/" + filename + "\n")
file.close()

# %%
# %cat train.txt #creating train txt file
# Out:
# ../train/images/Abyssinian_100_jpg.rf.ac857e7c2457ab89dd6edacb21e6fb7c.jpg
# ../train/images/Abyssinian_102_jpg.rf.e89f4c1898ba0c2bf4ff8b24f47a5f4c.jpg
# ../train/images/Abyssinian_103_jpg.rf.d6f56d3f97d62e11ab1c43036e98161f.jpg
# ../train/images/Abyssinian_104_jpg.rf.b9b83b115d919cae9c0cd249048855d2.jpg
# ../train/images/Abyssinian_107_jpg.rf.5a3e1331a1aba7847b3d02d4a3235ea4.jpg
# ../train/images/Abyssinian_108_jpg.rf.d30f63f4403f3540221ec3ab58a948d0.jpg
# ../train/images/Abyssinian_109_jpg.rf.687f0c760f6ef790ea030c0fcc3b14de.jpg
# ../train/images/Abyssinian_10_jpg.rf.4ea1ee7cc1c302cedfddac6b7b8433e0.jpg
# ../train/images/Abyssinian_110_jpg.rf.034902ccec7888913c2ca80336e70dab.jpg
# ../train/images/Abyssinian_111_jpg.rf.9e166839baadff6b365fe76e54185357.jpg
# ../train/images/Abyssinian_112_jpg.rf.769a3690becfa9d6c61ca6e4fb31b99c.jpg
# ../train/images/Abyssinian_113_jpg.rf.ce2a3460cb5e18e4b51e4ec12a219e61.jpg
# ../train/images/Abyssinian_115_jpg.rf.cd93ec881f2474e717136b4a3d81aed9.jpg
# ...

# %%
# %cd ../../test
# Out:
# /content/gdrive/MyDrive/proj3/test

# %%
# %cd images
# Out:
# /content/gdrive/MyDrive/proj3/valid/images

# %%
# create Ultralytics specific text file of validation images
file = open("test.txt", "w") 
for root, dirs, files in os.walk("."):
    for filename in files:
      # print("../test/images/" + filename)
      if filename == "test.txt":
        pass
      else:
        file.write("../test/images/" + filename + "\n")
file.close()

# %%
# %cat test.txt #creating test.txt file
# Out:
# ../test/images/Abyssinian_127_jpg.rf.4425d22917ead085ad038931b4806c8f.jpg
# ../test/images/Abyssinian_131_jpg.rf.e8acfb60e4d01529586b9d81930b35a2.jpg
# ../test/images/Abyssinian_149_jpg.rf.84b8351968b42b38478e0b6c35d58d07.jpg
# ../test/images/Abyssinian_155_jpg.rf.b0d3e78a69efe3c9aa7bd4416a51e105.jpg
# ../test/images/Abyssinian_15_jpg.rf.0e12ac0df99238e4f77a9eb02877b769.jpg
# ../test/images/Abyssinian_167_jpg.rf.de4ef71b17d239eb8920914948d63627.jpg
# ../test/images/Abyssinian_174_jpg.rf.65d50b9681532f2d3cf3773225103cbf.jpg
# ../test/images/Bengal_103_jpg.rf.6fc1e15891e15c765973d915273da8c1.jpg
# ../test/images/Bengal_109_jpg.rf.9e3729d26315213b3ad2b8463cf28fbe.jpg
# ../test/images/Bengal_116_jpg.rf.09d4aad1ebafec9ee2129dfb152edc6a.jpg
# ../test/images/Bengal_118_jpg.rf.0735c8c0e850aefb241572419eaf538d.jpg
# ../test/images/Bengal_13_jpg.rf.6495dd837b9a818cefede1c91df0cfe4.jpg
# ../test/images/Bengal_141_jpg.rf.333a69642e396ba09afe1ed4c990d989.jpg
# ...

# %%
# %cd ../../valid
# Out:
# [Errno 2] No such file or directory: '../../valid'
# /

# %%
# %cd images
# Out:
# /content/gdrive/MyDrive/proj3/valid/images

# %%
# create Ultralytics specific text file of validation images
file = open("valid.txt", "w") 
for root, dirs, files in os.walk("."):
    for filename in files:
      # print("../test/images/" + filename)
      if filename == "valid.txt":
        pass
      else:
        file.write("../valid/images/" + filename + "\n")
file.close()

# %%
# %cat valid.txt #creating valid.txt file
# Out:
# ../valid/images/Abyssinian_101_jpg.rf.006c8a3b7dce28aa52d5a961e9a1f792.jpg
# ../valid/images/Abyssinian_105_jpg.rf.10540388023430923121ad33d4908919.jpg
# ../valid/images/Abyssinian_106_jpg.rf.6c8b6992bc99bf7bb1e61fd44a8d8569.jpg
# ../valid/images/Abyssinian_114_jpg.rf.618711923c97fb8f55f5c84d55ec6c38.jpg
# ../valid/images/Abyssinian_120_jpg.rf.34766835079179a4a72ab7aadd07d7e6.jpg
# ../valid/images/Abyssinian_135_jpg.rf.352ae86ed1f7047b33dcf324032f1a2c.jpg
# ../valid/images/Abyssinian_13_jpg.rf.69b0aeb51dd886b8f02e08e32f560467.jpg
# ../valid/images/Abyssinian_164_jpg.rf.c7a8da687e0385e2672ecccbfc6e06bf.jpg
# ../valid/images/Abyssinian_166_jpg.rf.144aec8b0b9657d4eec0f35b0f3a3b44.jpg
# ../valid/images/Abyssinian_169_jpg.rf.0242c5e204c6fcd5528283ddaaf64485.jpg
# ../valid/images/Abyssinian_16_jpg.rf.6e84946dfb43edd6b29862ec50dcf374.jpg
# ../valid/images/Abyssinian_170_jpg.rf.d699052ee67c75786e51e80ce815e09e.jpg
# ../valid/images/Abyssinian_172_jpg.rf.0f64a22bb473537ba20cc7cb010c184c.jpg
# ...

# %%
# %cd /content/gdrive/MyDrive/proj3
# Out:
# /content/gdrive/MyDrive/proj3

# %%
# !git clone https://github.com/AlexeyAB/darknet #getting darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15502, done.
# remote: Total 15502 (delta 0), reused 0 (delta 0), pack-reused 15502
# Receiving objects: 100% (15502/15502), 14.17 MiB | 7.98 MiB/s, done.
# Resolving deltas: 100% (10403/10403), done.
# Updating files: 100% (2057/2057), done.

# %%
# %cd proj3
# Out:
# [Errno 2] No such file or directory: 'proj3'
# /content/gdrive/MyDrive/proj3/darknet

# %%
# %cd darknet
# Out:
# /content/gdrive/MyDrive/proj3/darknet

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile

# %%
"/content/gdrive/MyDrive/proj3/darknet/Makefile"
# Out:
# '/content/gdrive/MyDrive/proj3/darknet/Makefile'

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# %pwd
# Out:
# '/content/gdrive/MyDrive/proj3/darknet'

# %%
# %cd ..
# Out:
# /content/gdrive/MyDrive/proj3

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74 #downlodaing untraind weight for yolov3
# Out:
# --2023-02-21 13:31:25--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M  62.3MB/s    in 2.5s
#
# 2023-02-21 13:31:28 (62.3 MB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %%
! ./darknet/darknet detector train /content/gdrive/MyDrive/proj3/detector.data /content/gdrive/MyDrive/proj3/cfg/yolov3-custom.cfg darknet53.conv.74 -dont_show #trainnig network
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 251322, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.922501), count: 4, class_loss = 0.001248, iou_loss = 0.061852, total_loss = 0.063100
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 251326, rewritten_bbox = 0.000000 %
# ...

# %%
# %cd darknet
# Out:
# /content/gdrive/MyDrive/proj3/darknet

# %%
! ./darknet detector map /content/gdrive/MyDrive/proj3/detector.data /content/gdrive/MyDrive/proj3/cfg/yolov3-custom.cfg /content/gdrive/MyDrive/proj3/backup/yolov3-custom_final.weights #checking whigtes
# Out:
#  CUDA-version: 11060 (11060), cuDNN: 8.4.0, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 4.2.0
#  0 : compute_capability = 800, cudnn_half = 1, GPU: NVIDIA A100-SXM4-40GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
